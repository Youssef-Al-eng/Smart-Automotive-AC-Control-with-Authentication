# %%
import os
import cv2
from ultralytics import YOLO

# Load YOLOv8 model
yolo_model = YOLO("yolov8n.pt")

# Function to detect and crop face with YOLO
def crop_face_yolo(image_path, output_path):
    img = cv2.imread(image_path)
    if img is None:
        print(f"Could not read: {image_path}")
        return False
    
    results = yolo_model(image_path)
    boxes = results[0].boxes.xyxy.cpu().numpy()

    if len(boxes) > 0:
        x1, y1, x2, y2 = map(int, boxes[0][:4])
        face = img[y1:y2, x1:x2]

        if face.size == 0:
            return False

        cv2.imwrite(output_path, face)
        return True
    return False

# Dataset paths
dataset_dir = r"C:\Users\hp\Most perfect"
cropped_dir = r"C:\Users\hp\Most perfect\cropped_dataset"
os.makedirs(cropped_dir, exist_ok=True)

# Loop through dataset folders
for person in os.listdir(dataset_dir):
    person_dir = os.path.join(dataset_dir, person)

    # 🔥 Skip files — only process folders
    if not os.path.isdir(person_dir):
        print("Skipping file:", person_dir)
        continue

    cropped_person_dir = os.path.join(cropped_dir, person)
    os.makedirs(cropped_person_dir, exist_ok=True)

    # Iterate through images inside each person's folder
    for img_file in os.listdir(person_dir):
        input_path = os.path.join(person_dir, img_file)

        # Skip non-files / skip non-images
        if not os.path.isfile(input_path):
            continue

        if img_file.lower().endswith((".jpg", ".jpeg", ".png")):
            output_path = os.path.join(cropped_person_dir, img_file)

            if not crop_face_yolo(input_path, output_path):
                print(f"No face detected in: {input_path}")

print("Cropping complete. Use", cropped_dir, "for training.")
# Out:
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (1).jpg: 640x640 1 person, 129.7ms
# Speed: 6.3ms preprocess, 129.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (10).jpg: 640x640 1 person, 166.6ms
# Speed: 6.8ms preprocess, 166.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (11).jpg: 640x640 1 person, 121.0ms
# Speed: 4.9ms preprocess, 121.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (12).jpg: 640x640 1 horse, 100.1ms
# Speed: 4.6ms preprocess, 100.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (13).jpg: 640x640 1 person, 100.3ms
# Speed: 5.4ms preprocess, 100.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (14).jpg: 640x640 1 person, 215.3ms
# Speed: 7.4ms preprocess, 215.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (15).jpg: 640x640 1 person, 123.0ms
# Speed: 6.7ms preprocess, 123.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (16).jpg: 640x640 (no detections), 138.6ms
# Speed: 3.7ms preprocess, 138.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# No face detected in: C:\Users\hp\Most perfect\Abdalah Mohamed\img (16).jpg
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (17).jpg: 640x640 (no detections), 142.0ms
# Speed: 8.9ms preprocess, 142.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# No face detected in: C:\Users\hp\Most perfect\Abdalah Mohamed\img (17).jpg
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (18).jpg: 640x640 1 person, 1 scissors, 146.7ms
# Speed: 4.1ms preprocess, 146.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (19).jpg: 640x640 1 person, 158.5ms
# Speed: 5.7ms preprocess, 158.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (2).jpg: 640x640 1 person, 1 cup, 132.9ms
# Speed: 6.2ms preprocess, 132.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (20).jpg: 640x640 (no detections), 158.9ms
# Speed: 4.6ms preprocess, 158.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# No face detected in: C:\Users\hp\Most perfect\Abdalah Mohamed\img (20).jpg
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (21).jpg: 640x640 1 person, 150.6ms
# Speed: 6.6ms preprocess, 150.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (22).jpg: 640x640 1 person, 124.1ms
# Speed: 6.5ms preprocess, 124.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (23).jpg: 640x640 1 person, 125.0ms
# Speed: 4.7ms preprocess, 125.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (3).jpg: 640x640 (no detections), 139.5ms
# Speed: 4.7ms preprocess, 139.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No face detected in: C:\Users\hp\Most perfect\Abdalah Mohamed\img (3).jpg
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (4).jpg: 640x640 1 person, 132.5ms
# Speed: 6.3ms preprocess, 132.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (5).jpg: 640x640 1 person, 113.3ms
# Speed: 4.6ms preprocess, 113.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (6).jpg: 640x640 1 person, 176.4ms
# Speed: 6.3ms preprocess, 176.4ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (7).jpg: 640x640 (no detections), 140.6ms
# Speed: 8.8ms preprocess, 140.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No face detected in: C:\Users\hp\Most perfect\Abdalah Mohamed\img (7).jpg
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (8).jpg: 640x640 1 person, 98.4ms
# Speed: 4.2ms preprocess, 98.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Abdalah Mohamed\img (9).jpg: 640x640 1 person, 106.8ms
# Speed: 6.9ms preprocess, 106.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Skipping file: C:\Users\hp\Most perfect\Face Recognition .ipynb
# Skipping file: C:\Users\hp\Most perfect\facenet_embedder.note
# Skipping file: C:\Users\hp\Most perfect\facenet_keras.h5
# Skipping file: C:\Users\hp\Most perfect\l2_normalizer.note
# Skipping file: C:\Users\hp\Most perfect\Live_test .ipynb
# Skipping file: C:\Users\hp\Most perfect\rf_model.pkl
# Skipping file: C:\Users\hp\Most perfect\scaler.pkl
# Skipping file: C:\Users\hp\Most perfect\streamlit.py
# Skipping file: C:\Users\hp\Most perfect\svm_model.pkl
# Skipping file: C:\Users\hp\Most perfect\yolov8n.pt
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (1).jpg: 608x640 2 persons, 167.9ms
# Speed: 5.7ms preprocess, 167.9ms inference, 2.4ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (10).jpg: 512x640 1 person, 114.5ms
# Speed: 3.2ms preprocess, 114.5ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (11).jpg: 640x640 1 person, 142.9ms
# Speed: 6.9ms preprocess, 142.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (12).jpg: 640x640 1 person, 147.9ms
# Speed: 4.6ms preprocess, 147.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (13).jpg: 640x640 1 person, 111.8ms
# Speed: 6.2ms preprocess, 111.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (14).jpg: 640x576 2 persons, 156.1ms
# Speed: 5.7ms preprocess, 156.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (15).jpg: 640x416 1 person, 130.3ms
# Speed: 2.6ms preprocess, 130.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (16).jpg: 640x608 2 persons, 128.2ms
# Speed: 5.4ms preprocess, 128.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (17).jpg: 640x576 4 persons, 94.2ms
# Speed: 4.8ms preprocess, 94.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (2).jpg: 512x640 1 person, 89.1ms
# Speed: 3.1ms preprocess, 89.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (3).jpg: 448x640 1 person, 103.3ms
# Speed: 2.5ms preprocess, 103.3ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (4).jpg: 480x640 1 person, 1 bottle, 100.4ms
# Speed: 2.8ms preprocess, 100.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (5).jpg: 640x512 1 person, 114.5ms
# Speed: 4.1ms preprocess, 114.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (6).jpg: 640x512 1 person, 81.2ms
# Speed: 5.8ms preprocess, 81.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (7).jpg: 640x544 3 persons, 168.2ms
# Speed: 4.2ms preprocess, 168.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (8).jpg: 576x640 1 person, 161.1ms
# Speed: 5.8ms preprocess, 161.1ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\hp\Most perfect\Yousef Alaa\img (9).jpg: 576x640 1 person, 152.7ms
# Speed: 6.5ms preprocess, 152.7ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 640)
# Cropping complete. Use C:\Users\hp\Most perfect\cropped_dataset for training.

# %%
import os
print("✅ Dataset contains:", os.listdir(r"C:\Users\hp\Most perfect\cropped_dataset"))
# Out:
# ✅ Dataset contains: ['Abdalah Mohamed', 'Yousef Alaa']

# %%
import os
import cv2
import numpy as np
import joblib
from datetime import datetime
from mtcnn import MTCNN
from keras_facenet import FaceNet
from sklearn.preprocessing import LabelEncoder, Normalizer, StandardScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from ultralytics import YOLO
from collections import deque
import tensorflow as tf

# %%
DATASET_DIR = r"C:\Users\hp\Most perfect\cropped_dataset"
IMG_SIZE = (160, 160)
MARGIN = 20
AUG_PER_IMAGE = 3          
UNKNOWN_THRESHOLD = 0.85

# %%
SVM_PATH = r"C:\Users\hp\Most perfect\svm_model.pkl"
ENCODER_PATH = r"C:\Users\hp\Most perfect\encoder.pkl"
SCALER_PATH = r"C:\Users\hp\Most perfect\scaler.pkl"
RF_PATH = r"C:\Users\hp\Most perfect\rf_model.pkl"
L2_FLAG_PATH = r"C:\Users\hp\Most perfect\l2_normalizer.note"
FACENET_NAME = r"C:\Users\hp\Most perfect\facenet_embedder.note"
YOLO_MODEL_PATH = r"C:\Users\hp\Most perfect\yolov8n.pt"

# %%
detector = MTCNN()
embedder = FaceNet()
yolo_model = YOLO("yolov8n.pt")
# Out:
# Exception ignored in: <_io.BufferedReader>
# Traceback (most recent call last):
#   File "C:\Users\hp\anaconda3\Lib\site-packages\lz4\frame\__init__.py", line 753, in flush
#     self._fp.flush()
# ValueError: I/O operation on closed file.
# Exception ignored in: <_io.BufferedReader>
# Traceback (most recent call last):
#   File "C:\Users\hp\anaconda3\Lib\site-packages\lz4\frame\__init__.py", line 753, in flush
#     self._fp.flush()
# ValueError: I/O operation on closed file.
# Exception ignored in: <_io.BufferedReader>
# Traceback (most recent call last):
#   File "C:\Users\hp\anaconda3\Lib\site-packages\lz4\frame\__init__.py", line 753, in flush
#     self._fp.flush()
# ValueError: I/O operation on closed file.

# %%
def square_crop_with_margin(box, img_w, img_h, margin=MARGIN):
    x, y, w, h = box
    x, y = abs(x), abs(y)
    x1, y1 = max(0, x - margin), max(0, y - margin)
    x2, y2 = min(img_w, x + w + margin), min(img_h, y + h + margin)
    bw, bh = x2 - x1, y2 - y1
    side = max(bw, bh)
    cx = x1 + bw // 2
    cy = y1 + bh // 2
    x1 = max(0, cx - side // 2)
    y1 = max(0, cy - side // 2)
    x2 = min(img_w, x1 + side)
    y2 = min(img_h, y1 + side)
    return x1, y1, x2, y2

# %%
def align_face(image, box, landmarks=None):
    if landmarks is not None:
        left_eye = np.array(landmarks[0][0])  
        right_eye = np.array(landmarks[1][0])
        angle = np.arctan2(right_eye[1] - left_eye[1], right_eye[0] - left_eye[0]) * 180 / np.pi
        M = cv2.getRotationMatrix2D((image.shape[1]//2, image.shape[0]//2), angle, 1.0)
        aligned = cv2.warpAffine(image, M, (image.shape[1], image.shape[0]))
        x1, y1, x2, y2 = square_crop_with_margin(box, image.shape[1], image.shape[0])
        return aligned[y1:y2, x1:x2]
    else:
        x1, y1, x2, y2 = square_crop_with_margin(box, image.shape[1], image.shape[0])
        return image[y1:y2, x1:x2]

# %%
def extract_face(path, required_size=IMG_SIZE):
    img = cv2.imread(path)
    if img is None:
        print(f" Could not read image: {path}")
        return None
    rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = detector.detect_faces(rgb)
    if not results:
        results_yolo = yolo_model(rgb)
        boxes = results_yolo[0].boxes
        if len(boxes) > 0:
            for box in boxes:
                if int(box.cls) == 0:  # Class 0: 'person'
                    box_coords = box.xyxy[0].cpu().numpy()
                    x1, y1, x2, y2 = map(int, box_coords)
                    face = rgb[y1:y2, x1:x2]
                    h, w = face.shape[:2]
                    center_x, center_y = w // 2, h // 2
                    angle = 0  
                    M = cv2.getRotationMatrix2D((center_x, center_y), angle, 1.0)
                    face = cv2.warpAffine(face, M, (w, h))
                    break
            else:
                print(f" No 'person' detected in fallback: {path}")
                return None
        else:
            print(f" No detection in fallback: {path}")
            return None
    else:
        box = results[0]['box']
        landmarks = [[results[0]['keypoints']['left_eye']], [results[0]['keypoints']['right_eye']]]
        face = align_face(rgb, box, landmarks)
    if face.size == 0:
        return None
    face = cv2.resize(face, required_size)
    face = face.astype("float32") / 255.0
    return face

# %%
def augment_face(face_rgb_01):
    aug_samples = []

    flipped = cv2.flip(face_rgb_01, 1)
    aug_samples.append(flipped)
    
    beta = np.random.uniform(-30, 30)
    bgr = cv2.cvtColor((face_rgb_01*255).astype(np.uint8), cv2.COLOR_RGB2BGR)
    bright = cv2.convertScaleAbs(bgr, alpha=1.0, beta=beta)
    bright = cv2.cvtColor(bright, cv2.COLOR_BGR2RGB).astype(np.float32)/255.0
    aug_samples.append(bright)

    angle = np.random.uniform(-15, 15)
    M = cv2.getRotationMatrix2D((IMG_SIZE[0]//2, IMG_SIZE[1]//2), angle, 1.0)
    rot = cv2.warpAffine((face_rgb_01*255).astype(np.uint8), M, IMG_SIZE)
    rot = rot.astype(np.float32)/255.0
    aug_samples.append(rot)

    blur = cv2.GaussianBlur((face_rgb_01*255).astype(np.uint8), (3,3), 0)
    blur = blur.astype(np.float32)/255.0
    aug_samples.append(blur)

    shear = np.random.uniform(-0.1, 0.1)
    M = np.array([[1, shear, 0], [0, 1, 0]], dtype=np.float32)
    shear_img = cv2.warpAffine((face_rgb_01*255).astype(np.uint8), M, IMG_SIZE)
    shear_img = shear_img.astype(np.float32)/255.0
    aug_samples.append(shear_img)
    np.random.shuffle(aug_samples)
    return aug_samples[:AUG_PER_IMAGE]

# %%
def face_to_embedding(face_rgb_01):
    face_255 = (face_rgb_01*255).astype(np.uint8)
    face_255 = np.expand_dims(face_255, 0)
    embs = embedder.embeddings(face_255)
    return embs[0]

# %%
def load_dataset(dataset_dir=DATASET_DIR):
    X_embeds, y_labels = [], []
    persons = [p for p in os.listdir(dataset_dir) if os.path.isdir(os.path.join(dataset_dir, p))]
    persons.sort()
    total_imgs = 0

    for person in persons:
        person_dir = os.path.join(dataset_dir, person)
        for fn in os.listdir(person_dir):
            if not fn.lower().endswith((".jpg", ".jpeg", ".png", ".bmp", ".webp")):
                continue
            total_imgs += 1
            path = os.path.join(person_dir, fn)
            face = extract_face(path)
            if face is None:
                print(f" No face detected or unreadable: {path}")
                continue

            emb = face_to_embedding(face)
            X_embeds.append(emb)
            y_labels.append(person)

            for aug in augment_face(face):
                emb_aug = face_to_embedding(aug)
                X_embeds.append(emb_aug)
                y_labels.append(person)

    X_embeds = np.array(X_embeds, dtype=np.float32)
    y_labels = np.array(y_labels)
    print(f" Loaded {len(y_labels)} samples (from ~{total_imgs} files) for {len(set(y_labels))} people.")
    return X_embeds, y_labels

# %%
def train(dataset_dir=DATASET_DIR, test_size=0.2, random_state=42):
    
    print(" Loading dataset...")
    X, y = load_dataset(dataset_dir)
    encoder = LabelEncoder()
    y_enc = encoder.fit_transform(y)
    
    print(" Normalizing features...")
    l2 = Normalizer(norm="l2")
    X_l2 = l2.transform(X)
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X_l2)
    X_tr, X_val, y_tr, y_val = train_test_split(X_scaled, y_enc, test_size=test_size, random_state=random_state, stratify=y_enc)
    
    print(" Training SVM with grid search...")
    svm = SVC(probability=True, class_weight="balanced")
    param_grid = {'C': [0.1, 1, 10, 100], 'kernel': ['linear', 'rbf']}
    grid_search = GridSearchCV(svm, param_grid, cv=5, scoring='accuracy')
    grid_search.fit(X_tr, y_tr)
    print(f"Best SVM params: {grid_search.best_params_}")
    svm = grid_search.best_estimator_

    
    rf = RandomForestClassifier(n_estimators=100, random_state=random_state)
    rf.fit(X_tr, y_tr)

    y_pred_svm = svm.predict(X_val)
    acc_svm = accuracy_score(y_val, y_pred_svm)
    print(f" SVM Validation Accuracy: {acc_svm:.4f}")
    print(" SVM Classification Report:")
    print(classification_report(y_val, y_pred_svm, target_names=encoder.classes_))

    y_pred_rf = rf.predict(X_val)
    acc_rf = accuracy_score(y_val, y_pred_rf)
    print(f" RF Validation Accuracy: {acc_rf:.4f}")
    
    joblib.dump(svm, SVM_PATH)
    joblib.dump(rf, r"C:\Users\hp\Most perfect\rf_model.pkl")
    joblib.dump(encoder, ENCODER_PATH)
    joblib.dump(scaler, SCALER_PATH)
    with open(L2_FLAG_PATH, "w", encoding="utf-8") as f:
        f.write(f"L2 normalization applied @ {datetime.now()}\n")
    with open(FACENET_NAME, "w", encoding="utf-8") as f:
        f.write(f"Embeddings by keras-facenet @ {datetime.now()}\n")
    print("Models saved:", SVM_PATH, ENCODER_PATH, SCALER_PATH, r"C:\Users\hp\Most perfect\rf_model.pkl")
    return acc_svm, acc_rf

# %%
def load_models(svm_path=SVM_PATH, rf_path=RF_PATH, encoder_path=ENCODER_PATH, scaler_path=SCALER_PATH):
    if not (os.path.exists(svm_path) and os.path.exists(rf_path) and os.path.exists(encoder_path) and os.path.exists(scaler_path)):
        print(f" Model files missing: {svm_path}, {rf_path}, {encoder_path}, {scaler_path}")
        return None, None, None, None, None
    try:
        svm = joblib.load(svm_path)
        rf = joblib.load(rf_path)
        encoder = joblib.load(encoder_path)
        scaler = joblib.load(scaler_path)
        l2 = Normalizer(norm="l2")
        print(f"Loaded SVM, RF, encoder, scaler, and L2 normalizer")
        return svm, rf, encoder, scaler, l2
    except Exception as e:
        print(f"Error loading models: {str(e)}")
        return None, None, None, None, None

# %%
def realtime_recognition():
    svm, rf, encoder, scaler, l2 = load_models()
    if svm is None:
        return
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print("Error: Could not open camera.")
        return
    win_name = "Real-Time Face Recognition (Press 'q' to quit)"
    pred_queues = {}  
    MIN_QUEUE_SIZE = 2  

    def match_box(new_box, old_boxes):
        if not old_boxes:
            return None
        nx1, ny1, nw, nh = new_box
        new_center = (nx1 + nw / 2, ny1 + nh / 2)
        min_dist = float('inf')
        matched_key = None
        for old_box in old_boxes:
            ox1, oy1, ow, oh = old_box
            old_center = (ox1 + ow / 2, oy1 + oh / 2)
            dist = ((new_center[0] - old_center[0])**2 + (new_center[1] - old_center[1])**2)**0.5
            if dist < min_dist and dist < 100:  
                min_dist = dist
                matched_key = tuple(old_box)
        return matched_key

    last_boxes = []
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                print(" Failed to grab frame")
                break
            rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            faces = []
            boxes_to_display = []
            results = detector.detect_faces(rgb)
            if results:
                for res in results:
                    box = res['box']
                    landmarks = [[res['keypoints']['left_eye']], [res['keypoints']['right_eye']]]
                    face = align_face(rgb, box, landmarks)
                    if face.size == 0:
                        continue
                    faces.append((face, box))
                    boxes_to_display.append(box)
            else:
                results_yolo = yolo_model(rgb)
                boxes = results_yolo[0].boxes
                for box in boxes:
                    if int(box.cls) != 0:  
                        continue
                    box_coords = box.xyxy[0].cpu().numpy()
                    x1, y1, x2, y2 = map(int, box_coords)
                    face = align_face(rgb, [x1, y1, x2-x1, y2-y1])
                    if face.size == 0:
                        continue
                    faces.append((face, [x1, y1, x2-x1, y2-y1]))
                    boxes_to_display.append([x1, y1, x2-x1, y2-y1])
            last_boxes = boxes_to_display
            if not faces:
                cv2.imshow(win_name, frame)
                continue
   
            for face, box in faces:
                face = cv2.resize(face, IMG_SIZE).astype(np.float32) / 255.0
                emb = face_to_embedding(face).reshape(1, -1)
                emb = l2.transform(emb)
                emb = scaler.transform(emb)
                probs_svm = svm.predict_proba(emb)[0]
                probs_rf = rf.predict_proba(emb)[0]
                probs = (probs_svm + probs_rf) / 2
                pred_idx = np.argmax(probs)
                pred_conf = probs[pred_idx]
                box_key = match_box(box, last_boxes)
                
                if box_key is None:
                    box_key = tuple(box)
                if box_key not in pred_queues:
                    pred_queues[box_key] = deque(maxlen=5)
                pred_queues[box_key].append((pred_idx, pred_conf))
                if len(pred_queues[box_key]) >= MIN_QUEUE_SIZE:
                    avg_conf = np.mean([conf for _, conf in pred_queues[box_key]])
                    mode_idx = max(set([idx for idx, _ in pred_queues[box_key]]), key=[idx for idx, _ in pred_queues[box_key]].count)
                    pred_name = encoder.inverse_transform([mode_idx])[0]
                    display = f"{pred_name} ({avg_conf*100:.1f}%)" if avg_conf >= UNKNOWN_THRESHOLD else f"Unknown ({avg_conf*100:.1f}%)"
                    color = (0, 255, 0) if avg_conf >= UNKNOWN_THRESHOLD else (0, 0, 255)
                else:
                    pred_name = encoder.inverse_transform([pred_idx])[0]
                    display = f"{pred_name} ({pred_conf*100:.1f}%)" if pred_conf >= UNKNOWN_THRESHOLD else f"Unknown ({pred_conf*100:.1f}%)"
                    color = (0, 255, 0) if pred_conf >= UNKNOWN_THRESHOLD else (0, 0, 255)
                x1, y1, x2, y2 = square_crop_with_margin(box, rgb.shape[1], rgb.shape[0])
                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                cv2.putText(frame, display, (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)
                
            active_keys = [tuple(box) for box in boxes_to_display]
            pred_queues = {k: q for k, q in pred_queues.items() if k in active_keys}
            cv2.imshow(win_name, frame)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                print("👋 Closing camera...")
                break
            if cv2.getWindowProperty(win_name, cv2.WND_PROP_VISIBLE) < 1:
                break
    finally:
        cap.release()
        cv2.destroyAllWindows()
        cv2.waitKey(1)

if __name__ == "__main__":
    print("Real-Time Face Recognition ")
    print(f"Dataset: {DATASET_DIR}")
    acc_svm, acc_rf = train(DATASET_DIR)
    svm, rf, encoder, scaler, l2 = load_models()
    realtime_recognition()
# Out:
# Real-Time Face Recognition
# Dataset: C:\Users\hp\Most perfect\cropped_dataset
#  Loading dataset...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
#
# 0: 640x640 1 person, 100.5ms
# Speed: 5.4ms preprocess, 100.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#
# 0: 608x640 (no detections), 107.7ms
# Speed: 4.8ms preprocess, 107.7ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 640)
#  No detection in fallback: C:\Users\hp\Most perfect\cropped_dataset\Abdalah Mohamed\img (8).jpg
#  No face detected or unreadable: C:\Users\hp\Most perfect\cropped_dataset\Abdalah Mohamed\img (8).jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#  Loaded 156 samples (from ~40 files) for 2 people.
#  Normalizing features...
#  Training SVM with grid search...
# Best SVM params: {'C': 0.1, 'kernel': 'linear'}
#  SVM Validation Accuracy: 1.0000
#  SVM Classification Report:
#                  precision    recall  f1-score   support
#
# Abdalah Mohamed       1.00      1.00      1.00        18
#     Yousef Alaa       1.00      1.00      1.00        14
#
#        accuracy                           1.00        32
#       macro avg       1.00      1.00      1.00        32
#    weighted avg       1.00      1.00      1.00        32
#
#  RF Validation Accuracy: 1.0000
# Models saved: C:\Users\hp\Most perfect\svm_model.pkl C:\Users\hp\Most perfect\encoder.pkl C:\Users\hp\Most perfect\scaler.pkl C:\Users\hp\Most perfect\rf_model.pkl
# Loaded SVM, RF, encoder, scaler, and L2 normalizer
# Loaded SVM, RF, encoder, scaler, and L2 normalizer
#
# 0: 480x640 1 vase, 98.5ms
# Speed: 5.8ms preprocess, 98.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 118.7ms
# Speed: 3.3ms preprocess, 118.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.7ms
# Speed: 3.7ms preprocess, 103.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
#
# 0: 480x640 1 vase, 82.4ms
# Speed: 2.3ms preprocess, 82.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
#
# 0: 480x640 1 person, 72.7ms
# Speed: 2.7ms preprocess, 72.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
#
# 0: 480x640 (no detections), 82.5ms
# Speed: 4.6ms preprocess, 82.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.7ms
# Speed: 1.9ms preprocess, 78.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 👋 Closing camera...

# %%
realtime_recognition()
# Out:
# Loaded SVM, RF, encoder, scaler, and L2 normalizer
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 👋 Closing camera...
